# %%
#Load necessary libraries
import tensorflow as tf
from tensorflow.keras import layers,models,regularizers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
import pandas as pd
import time

# %%
#Load the datasets
(x_train,y_train),(x_test,y_test)=cifar10.load_data()
#Preprocess the dataset
x_train,x_test=x_train/255.0,x_test/255.0
y_train,y_test=to_categorical(y_train),to_categorical(y_test)

# %%
#Base Model
base_model=Sequential([
    Flatten(input_shape=(32,32,3)),
    Dense(256,activation='relu'),
    Dense(128,activation='relu'),
    Dense(64,activation='relu'),
    Dense(10,activation='softmax'), 
])
base_model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
st1=time.time()
base_model.fit(x_train,y_train,epochs=5,batch_size=64,validation_data=(x_test,y_test))
sp1=time.time()
bloss,bacc=base_model.evaluate(x_test,y_test)
btime_taken=round(sp1-st1,2)
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.3209 - loss: 1.8792 - val_accuracy: 0.3905 - val_loss: 1.7201
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.3982 - loss: 1.6804 - val_accuracy: 0.4076 - val_loss: 1.6400
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.4233 - loss: 1.6006 - val_accuracy: 0.4424 - val_loss: 1.5622
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.4441 - loss: 1.5480 - val_accuracy: 0.4444 - val_loss: 1.5518
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.4629 - loss: 1.5044 - val_accuracy: 0.4670 - val_loss: 1.4943
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4670 - loss: 1.4943

# %%
#Xavier Initializers
xavier_model=Sequential([
    Flatten(input_shape=(32,32,3)),
    Dense(256,activation='relu',kernel_initializer='glorot_uniform'),
    Dense(128,activation='relu',kernel_initializer='glorot_uniform'),
    Dense(64,activation='relu',kernel_initializer='glorot_uniform'),
    Dense(10,activation='softmax'), 
])
xavier_model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
st2=time.time()
xavier_model.fit(x_train,y_train,epochs=5,batch_size=64,validation_data=(x_test,y_test))
sp2=time.time()
xloss,xacc=xavier_model.evaluate(x_test,y_test)
xtime_taken=round(sp2-st2,2)
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.3163 - loss: 1.8860 - val_accuracy: 0.3641 - val_loss: 1.7754
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.3967 - loss: 1.6852 - val_accuracy: 0.4123 - val_loss: 1.6446
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.4248 - loss: 1.6055 - val_accuracy: 0.4201 - val_loss: 1.6098
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.4448 - loss: 1.5536 - val_accuracy: 0.4264 - val_loss: 1.5926
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.4606 - loss: 1.5093 - val_accuracy: 0.4437 - val_loss: 1.5588
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4437 - loss: 1.5588

# %%
#Kaiming Initializers
kaiming_model=Sequential([
    Flatten(input_shape=(32,32,3)),
    Dense(256,activation='relu',kernel_initializer='he_uniform'),
    Dense(128,activation='relu',kernel_initializer='he_uniform'),
    Dense(64,activation='relu',kernel_initializer='he_uniform'),
    Dense(10,activation='softmax'), 
])
kaiming_model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
st3=time.time()
kaiming_model.fit(x_train,y_train,epochs=5,batch_size=64,validation_data=(x_test,y_test))
sp3=time.time()
kloss,kacc=kaiming_model.evaluate(x_test,y_test)
ktime_taken=round(sp3-st3,2)
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.3155 - loss: 1.8888 - val_accuracy: 0.3761 - val_loss: 1.7366
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.3870 - loss: 1.7037 - val_accuracy: 0.4247 - val_loss: 1.6287
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4211 - loss: 1.6177 - val_accuracy: 0.4381 - val_loss: 1.5795
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.4406 - loss: 1.5630 - val_accuracy: 0.4526 - val_loss: 1.5423
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.4566 - loss: 1.5244 - val_accuracy: 0.4474 - val_loss: 1.5552
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4474 - loss: 1.5552

# %%
#DropOut
dropout_model=Sequential([
    Flatten(input_shape=(32,32,3)),
    Dense(256,activation='relu'),
    layers.Dropout(0.2),
    Dense(128,activation='relu'),
    layers.Dropout(0.2),
    Dense(64,activation='relu'),
    layers.Dropout(0.2),
    Dense(10,activation='softmax'), 
])
dropout_model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
st4=time.time()
dropout_model.fit(x_train,y_train,epochs=5,batch_size=64,validation_data=(x_test,y_test))
sp4=time.time()
dloss,dacc=dropout_model.evaluate(x_test,y_test)
dtime_taken=round(sp4-st4,2)
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.2319 - loss: 2.0508 - val_accuracy: 0.3073 - val_loss: 1.8890
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.2936 - loss: 1.9135 - val_accuracy: 0.3600 - val_loss: 1.7953
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.3150 - loss: 1.8698 - val_accuracy: 0.3692 - val_loss: 1.7752
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.3257 - loss: 1.8414 - val_accuracy: 0.3549 - val_loss: 1.7701
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.3319 - loss: 1.8248 - val_accuracy: 0.3808 - val_loss: 1.7454
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3808 - loss: 1.7454

# %%
#L2 Initializers
l2_model=Sequential([
    Flatten(input_shape=(32,32,3)),
    Dense(256,activation='relu',kernel_regularizer=regularizers.l2(0.001)),
    Dense(128,activation='relu',kernel_regularizer=regularizers.l2(0.001)),
    Dense(64,activation='relu',kernel_regularizer=regularizers.l2(0.001)),
    Dense(10,activation='softmax'), 
])
l2_model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
st5=time.time()
l2_model.fit(x_train,y_train,epochs=5,batch_size=64,validation_data=(x_test,y_test))
sp5=time.time()
lloss,lacc=l2_model.evaluate(x_test,y_test)
ltime_taken=round(sp5-st5,2)
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.3145 - loss: 2.0993 - val_accuracy: 0.3599 - val_loss: 1.8777
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.3803 - loss: 1.8265 - val_accuracy: 0.3840 - val_loss: 1.8156
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.4032 - loss: 1.7632 - val_accuracy: 0.4117 - val_loss: 1.7188
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.4195 - loss: 1.7161 - val_accuracy: 0.3881 - val_loss: 1.7774
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.4316 - loss: 1.6880 - val_accuracy: 0.4286 - val_loss: 1.7141
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4286 - loss: 1.7141

# %%
#Comparison between models
data={
    'Model':['Base Model','Xavier Initialization','Kaiming Initialization','Dropout','L2 Regulirization'],
    'Test Loss':[bloss,xloss,kloss,dloss,lloss],
    'Test Accuracy':[bacc,xacc,kacc,dacc,lacc],
    'Total time taken':[btime_taken,xtime_taken,ktime_taken,dtime_taken,ltime_taken]
}
df=pd.DataFrame(data)
print('Comparison between models \n')
print(df)
# Out:
# Comparison between models
#
#                     Model  Test Loss  Test Accuracy  Total time taken
# 0              Base Model   1.494307         0.4670             32.49
# 1   Xavier Initialization   1.558814         0.4437             36.01
# 2  Kaiming Initialization   1.555184         0.4474             36.94
# 3                 Dropout   1.745403         0.3808             39.09
# 4       L2 Regulirization   1.714092         0.4286             35.58
