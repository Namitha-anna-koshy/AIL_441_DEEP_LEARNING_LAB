# %%
#Import necessary libraries
import tensorflow as tf
from tensorflow.keras import layers,models
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt

# %%
#Split the dataset into training and testing
(x_train,y_train),(x_test,y_test) = cifar10.load_data()
#Preprocess the dataset
x_train,x_test=x_train/255.0,x_test/255.0
y_train,y_test=to_categorical(y_train),to_categorical(y_test)

# %%
def create_model(hidden_units=None,activation=None):
    model=Sequential([
        Flatten(input_shape=(32,32,3)),
        Dense(hidden_units[0],activation=activation),
        Dense(hidden_units[1],activation=activation),
        Dense(hidden_units[2],activation=activation),
        Dense(10,activation='softmax')
    ])
    return model

# %%
hidden_units_lists=[(512,256,128),(256,128,64),(1024,512,256)]
activation_list=['relu','tanh','sigmoid']
result_set={}
counter=1

# %%
for hidden_units in hidden_units_lists:
    for activation in activation_list:
        model=create_model(hidden_units=hidden_units,activation=activation)
        model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
        history=model.fit(x_train,y_train,epochs=5,batch_size=64,validation_data=(x_test,y_test))
        _,test_acc=model.evaluate(x_test,y_test)
        model_info={'Hidden Units':hidden_units,'Activation':activation,'Test_accuracy':round(test_acc*100,4)}
        result_set[counter]=model_info
        counter=counter+1
# Out:
# C:\Users\Namitha Anna Koshy\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.3256 - loss: 1.8687 - val_accuracy: 0.3547 - val_loss: 1.7706
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.4025 - loss: 1.6683 - val_accuracy: 0.4255 - val_loss: 1.5982
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.4337 - loss: 1.5818 - val_accuracy: 0.4218 - val_loss: 1.6130
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.4543 - loss: 1.5300 - val_accuracy: 0.4621 - val_loss: 1.5207
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.4686 - loss: 1.4842 - val_accuracy: 0.4473 - val_loss: 1.5567
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4473 - loss: 1.5567
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.2436 - loss: 2.0138 - val_accuracy: 0.2899 - val_loss: 1.9112
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.2959 - loss: 1.9083 - val_accuracy: 0.3029 - val_loss: 1.9139
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.3132 - loss: 1.8726 - val_accuracy: 0.3162 - val_loss: 1.8715
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.3251 - loss: 1.8508 - val_accuracy: 0.3198 - val_loss: 1.8453
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.3305 - loss: 1.8374 - val_accuracy: 0.3277 - val_loss: 1.8253
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3277 - loss: 1.8253
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.3022 - loss: 1.9067 - val_accuracy: 0.3305 - val_loss: 1.8190
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.3644 - loss: 1.7487 - val_accuracy: 0.3866 - val_loss: 1.7099
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.3931 - loss: 1.6797 - val_accuracy: 0.4041 - val_loss: 1.6647
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.4074 - loss: 1.6396 - val_accuracy: 0.3825 - val_loss: 1.7267
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.4205 - loss: 1.6074 - val_accuracy: 0.4209 - val_loss: 1.6090
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4209 - loss: 1.6090
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.3153 - loss: 1.8975 - val_accuracy: 0.3679 - val_loss: 1.7457
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.3848 - loss: 1.7103 - val_accuracy: 0.4042 - val_loss: 1.6620
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.4220 - loss: 1.6200 - val_accuracy: 0.4483 - val_loss: 1.5599
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.4422 - loss: 1.5612 - val_accuracy: 0.4393 - val_loss: 1.5790
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.4572 - loss: 1.5158 - val_accuracy: 0.4392 - val_loss: 1.5613
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4392 - loss: 1.5613
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.2747 - loss: 1.9695 - val_accuracy: 0.3013 - val_loss: 1.8998
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.3203 - loss: 1.8680 - val_accuracy: 0.3329 - val_loss: 1.8076
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.3424 - loss: 1.8156 - val_accuracy: 0.3656 - val_loss: 1.7848
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.3521 - loss: 1.7975 - val_accuracy: 0.3719 - val_loss: 1.7513
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.3617 - loss: 1.7768 - val_accuracy: 0.3850 - val_loss: 1.7180
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3850 - loss: 1.7180
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.2527 - loss: 2.0158 - val_accuracy: 0.3235 - val_loss: 1.8597
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.3424 - loss: 1.8180 - val_accuracy: 0.3541 - val_loss: 1.7779
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.3619 - loss: 1.7599 - val_accuracy: 0.3716 - val_loss: 1.7250
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.3786 - loss: 1.7138 - val_accuracy: 0.3859 - val_loss: 1.6976
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.3945 - loss: 1.6701 - val_accuracy: 0.3960 - val_loss: 1.6763
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3960 - loss: 1.6763
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.3154 - loss: 1.8848 - val_accuracy: 0.3792 - val_loss: 1.7465
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.3984 - loss: 1.6732 - val_accuracy: 0.4271 - val_loss: 1.6016
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.4341 - loss: 1.5818 - val_accuracy: 0.4301 - val_loss: 1.5866
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.4579 - loss: 1.5166 - val_accuracy: 0.4568 - val_loss: 1.5208
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.4734 - loss: 1.4739 - val_accuracy: 0.4585 - val_loss: 1.4966
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4585 - loss: 1.4966
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.1958 - loss: 2.1031 - val_accuracy: 0.2404 - val_loss: 2.0044
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.2468 - loss: 1.9784 - val_accuracy: 0.2206 - val_loss: 2.1095
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.2663 - loss: 1.9543 - val_accuracy: 0.2502 - val_loss: 1.9834
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.2873 - loss: 1.9245 - val_accuracy: 0.3120 - val_loss: 1.9037
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.2976 - loss: 1.9075 - val_accuracy: 0.3353 - val_loss: 1.8332
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3353 - loss: 1.8332
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.2832 - loss: 1.9333 - val_accuracy: 0.3411 - val_loss: 1.8078
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.3616 - loss: 1.7557 - val_accuracy: 0.3797 - val_loss: 1.7030
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.3861 - loss: 1.7005 - val_accuracy: 0.4013 - val_loss: 1.6532
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.4018 - loss: 1.6589 - val_accuracy: 0.3894 - val_loss: 1.6903
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.4147 - loss: 1.6203 - val_accuracy: 0.3873 - val_loss: 1.7197
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3873 - loss: 1.7197

# %%
for i in result_set:
    print(f'Model{i}:{result_set[i]}\n')
#Model with maximum accuracy
best_model=max(result_set.items(),key=lamba x:x[1]["Test accuracy"])
print(f"Model{best_model[0]}:{best_model[1]}")

# %%
class_names = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
random_indices = np.random.choice(len(x_test),3,replace=False)
sample_images = x_test[random_indices]
sample_labels = y_test[random_indices]
predictions=model.predict(sample_images)
for i in range(3):
    predicted_label=class_names[np.argmax(predictions[i])
    true_label = class_names[np.argmax(sample_labels[i])
    plt.imshow(sample_images[i])
    plt.title(f"True : {true_label}\n Predicted : {predicted_label}")
    plt.axis('off')
    plt.show()
